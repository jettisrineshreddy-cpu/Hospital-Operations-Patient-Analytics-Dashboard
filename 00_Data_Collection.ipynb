# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent
# Project Root
# Data Folders
RAW_FOLDER = PROJECT_ROOT / "data" / "raw"
CLEAN_FOLDER = PROJECT_ROOT / "data" / "cleaned"
FINAL_FOLDER = PROJECT_ROOT / "data" / "final"

print("Project:", PROJECT_ROOT)
print("Raw:", RAW_FOLDER)
# Out:
# Project: C:\Users\srine\Downloads\Hospital-Management-Analytics
# Raw: C:\Users\srine\Downloads\Hospital-Management-Analytics\data\raw

# %%
datasets = {
    "Patients": "Patients.csv",
    "Department": "Department.csv",
    "Doctor": "Doctor.csv",
    "Nurse": "Nurse.csv",
    "Helpers": "Helpers.csv",
    "Ward": "Ward.csv",
    "Room": "Room.csv",
    "Bed": "Bed.csv",
    "Appointment": "Appointment.csv",
    "MedicalRecord": "MedicalRecord.csv",
    "SurgeryRecord": "SurgeryRecord.csv",
    "RoomRecords": "RoomRecords.csv",
    "BedRecords": "BedRecords.csv",
    "StaffShift": "StaffShift.csv",
    "Equipment": "Equipment.csv",
    "Equipment_Usage": "Equipment_Usage.csv"
}

# %%
loaded_data = {}

for name, file in datasets.items():

    df = pd.read_csv(RAW_FOLDER / file)

    loaded_data[name] = df

    print(f" {name:<20} Rows: {df.shape[0]:<6} Columns: {df.shape[1]}")
# Out:
#  Patients             Rows: 1500   Columns: 7
#  Department           Rows: 31     Columns: 2
#  Doctor               Rows: 400    Columns: 8
#  Nurse                Rows: 500    Columns: 6
#  Helpers              Rows: 1100   Columns: 6
#  Ward                 Rows: 63     Columns: 3
#  Room                 Rows: 391    Columns: 3
#  Bed                  Rows: 500    Columns: 2
#  Appointment          Rows: 1000   Columns: 9
#  MedicalRecord        Rows: 3000   Columns: 11
#  SurgeryRecord        Rows: 1000   Columns: 11
#  RoomRecords          Rows: 1000   Columns: 9
#  BedRecords           Rows: 1000   Columns: 9
#  StaffShift           Rows: 2058   Columns: 7
#  Equipment            Rows: 164    Columns: 10
#  Equipment_Usage      Rows: 8172   Columns: 6

# %%
summary = pd.DataFrame({
    "Dataset": loaded_data.keys(),
    "Rows": [df.shape[0] for df in loaded_data.values()],
    "Columns": [df.shape[1] for df in loaded_data.values()]
})

summary
# Out:
#             Dataset  Rows  Columns
# 0          Patients  1500        7
# 1        Department    31        2
# 2            Doctor   400        8
# 3             Nurse   500        6
# 4           Helpers  1100        6
# 5              Ward    63        3
# 6              Room   391        3
# 7               Bed   500        2
# 8       Appointment  1000        9
# 9     MedicalRecord  3000       11
# 10    SurgeryRecord  1000       11
# 11      RoomRecords  1000        9
# 12       BedRecords  1000        9
# 13       StaffShift  2058        7
# 14        Equipment   164       10
# 15  Equipment_Usage  8172        6

# %%
print("="*60)
print("DATA COLLECTION COMPLETED")
print("="*60)

print(f"Datasets Loaded : {len(loaded_data)}")
# Out:
# ============================================================
# DATA COLLECTION COMPLETED
# ============================================================
# Datasets Loaded : 16
